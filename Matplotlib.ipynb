# %% [markdown]
# <a href="https://colab.research.google.com/github/Parishri07/Data-Science/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.random.randn(10000)
plt.hist(x,100)
plt.title('Normal Distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram.png')
plt.show()

# %%
plt.plot(5,5, '*', color='purple')
plt.show()

# .plot(kind='line') - to generate line graph
# .plot(kind='hist') - to generate histogram
